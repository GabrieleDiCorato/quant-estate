# %% [markdown]
# # Datamodel Test
#
# This notebook provides an updated and quick view on the datamodel to non-technical users.

# %%
import sys
from pathlib import Path

# Find the project root
project_root = Path().cwd().parent
print(f"Project root: {project_root}")

# Add project root to Python path (not just sources)
sys.path.insert(0, str(project_root))
print(f"Added to Python path: {project_root}")

# Now import from sources
import json
from sources.datamodel import RealEstateListing
from pprint import pprint
# Out:
# Project root: c:\Users\gabri\workspace\aida_projects\quant-estate
# Added to Python path: c:\Users\gabri\workspace\aida_projects\quant-estate

# %% [markdown]
# Since the datamodel was created using `pydantic`, we can create a datamodel schema very easily:

# %%
main_model_schema = RealEstateListing.model_json_schema()
print(json.dumps(main_model_schema, indent=2))
# Out:
# {
#   "$defs": {
#     "AirConditioningType": {
#       "enum": [
#         "central",
#         "independent",
#         "none"
#       ],
#       "title": "AirConditioningType",
#       "type": "string"
#     },
#     "ConditionType": {
#       "enum": [
#         "new",
#         "good",
#         "renovated",
#         "to_renovate",
#         "old"
#       ],
#       "title": "ConditionType",
#       "type": "string"
#     },
#     "ContractType": {
#       "enum": [
#         "sale",
#         "rent",
#         "rent_to_own"
#       ],
#       "title": "ContractType",
#       "type": "string"
#     },
#     "EnergyClass": {
#       "enum": [
#         "A",
#         "A1",
#         "A2",
#         "A3",
#         "A4",
#         "B",
#         "C",
#         "D",
#         "E",
#         "F",
#         "G"
#       ],
#       "title": "EnergyClass",
#       "type": "string"
#     },
#     "HeatingType": {
#       "enum": [
#         "central",
#         "independent",
#         "none"
#       ],
#       "title": "HeatingType",
#       "type": "string"
#     },
#     "PropertyType": {
#       "enum": [
#         "apartment",
#         "house",
#         "commercial",
#         "land",
#         "industrial"
#       ],
#       "title": "PropertyType",
#       "type": "string"
#     }
#   },
#   "additionalProperties": false,
#   "description": "Data model for a real estate property.",
#   "properties": {
#     "id": {
#       "description": "Unique identifier for the property",
#       "title": "Id",
#       "type": "string"
#     },
#     "title": {
#       "description": "Title of the property listing",
#       "title": "Title",
#       "type": "string"
#     },
#     "url": {
#       "description": "URL of the property listing",
#       "format": "uri",
#       "maxLength": 2083,
#       "minLength": 1,
#       "title": "Url",
#       "type": "string"
#     },
#     "formatted_price": {
#       "description": "Human-readable price string",
#       "title": "Formatted Price",
#       "type": "string"
#     },
#     "price_eur": {
#       "description": "Numeric price value in EUR",
#       "minimum": 0,
#       "title": "Price Eur",
#       "type": "number"
#     },
#     "formatted_maintenance_fee": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Human-readable maintenance fee string",
#       "title": "Formatted Maintenance Fee"
#     },
#     "maintenance_fee": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "number"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Monthly maintenance fee in EUR",
#       "title": "Maintenance Fee"
#     },
#     "type": {
#       "$ref": "#/$defs/PropertyType",
#       "description": "Property type (apartment, house, etc.)"
#     },
#     "contract": {
#       "$ref": "#/$defs/ContractType",
#       "description": "Type of contract (sale, rent, etc.)"
#     },
#     "condition": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/ConditionType"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Property condition (renovated, new, etc.)"
#     },
#     "is_new": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether the property is new construction",
#       "title": "Is New"
#     },
#     "is_luxury": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether this is a luxury property",
#       "title": "Is Luxury"
#     },
#     "surface_formatted": {
#       "description": "Human-readable surface area",
#       "title": "Surface Formatted",
#       "type": "string"
#     },
#     "surface": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "number"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Property surface area in square meters",
#       "title": "Surface"
#     },
#     "rooms": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Total number of rooms",
#       "title": "Rooms"
#     },
#     "floor": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Floor designation",
#       "title": "Floor"
#     },
#     "total_floors": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Total floors in building",
#       "title": "Total Floors"
#     },
#     "bathrooms": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Number of bathrooms",
#       "title": "Bathrooms"
#     },
#     "bedrooms": {
#       "anyOf": [
#         {
#           "minimum": 0,
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Number of bedrooms",
#       "title": "Bedrooms"
#     },
#     "balcony": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property has a balcony",
#       "title": "Balcony"
#     },
#     "terrace": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property has a terrace",
#       "title": "Terrace"
#     },
#     "elevator": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether building has elevators",
#       "title": "Elevator"
#     },
#     "garden": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property has a garden",
#       "title": "Garden"
#     },
#     "cellar": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property has a cellar",
#       "title": "Cellar"
#     },
#     "basement": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property has a basement",
#       "title": "Basement"
#     },
#     "furnished": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether property is furnished",
#       "title": "Furnished"
#     },
#     "build_year": {
#       "anyOf": [
#         {
#           "maximum": 2100,
#           "minimum": 1800,
#           "type": "integer"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Year the building was constructed",
#       "title": "Build Year"
#     },
#     "considerge": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether building has a concierge service",
#       "title": "Considerge"
#     },
#     "is_accessible": {
#       "anyOf": [
#         {
#           "type": "boolean"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Whether the property is accessible for people with disabilities",
#       "title": "Is Accessible"
#     },
#     "description": {
#       "description": "Property description",
#       "title": "Description",
#       "type": "string"
#     },
#     "other_amenities": {
#       "anyOf": [
#         {
#           "items": {
#             "type": "string"
#           },
#           "type": "array"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "List of other amenities or features",
#       "title": "Other Amenities"
#     },
#     "heating_type": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/HeatingType"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Type of heating system"
#     },
#     "air_conditioning": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/AirConditioningType"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Air conditioning type"
#     },
#     "energy_class": {
#       "anyOf": [
#         {
#           "$ref": "#/$defs/EnergyClass"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Energy efficiency class"
#     },
#     "city": {
#       "description": "City name",
#       "title": "City",
#       "type": "string"
#     },
#     "country": {
#       "description": "Country code",
#       "title": "Country",
#       "type": "string"
#     },
#     "address": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Full address of the property",
#       "title": "Address"
#     },
#     "parking_info": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "default": null,
#       "description": "Parking information (garage, street parking, etc.)",
#       "title": "Parking Info"
#     }
#   },
#   "required": [
#     "id",
#     "title",
#     "url",
#     "formatted_price",
#     "price_eur",
#     "type",
#     "contract",
#     "surface_formatted",
#     "description",
#     "city",
#     "country"
#   ],
#   "title": "RealEstateListing",
#   "type": "object"
# }
